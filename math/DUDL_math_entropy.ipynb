# %% [markdown]
# # COURSE: A deep understanding of deep learning
# ## SECTION: Math prerequisites
# ### LECTURE: Entropy and cross-entropy
# #### TEACHER: Mike X Cohen, sincxpress.com
# ##### COURSE URL: udemy.com/course/dudl/?couponCode=202208

# %%
# import libraries
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Reminder of entropy:
#
# $$H(p) = -\sum_x p(x)\log(p(x))$$

# %%
# probability of an event happening
p = .25

# NOT the correct formula!
H = -( p*np.log(p) )
print('Wrong entropy: ' + str(H))
# Out:
# Wrong entropy: 0.34657359027997264

# %%
# the correct way to compute entropy
x = [.25,.75]

H = 0
for p in x:
  H -= p*np.log(p)

print('Correct entropy: ' + str(H))
# Out:
# Correct entropy: 0.5623351446188083

# %%
# also correct, written out for N=2 events
H = -( p*np.log(p) + (1-p)*np.log(1-p) )
print('Correct entropy: ' + str(H))
# Out:
# Correct entropy: 0.5623351446188083

# %% [markdown]
# # Cross-entropy

# %%
# note: all probs must sum to 1!
p = [   1,0   ] # sum=1
q = [ 0.6,0.4 ] # sum=1

H = 0
for i in range(len(p)):
  H -= p[i]*np.log(q[i])

print('Cross entropy: ' + str(H))
# Out:
# Cross entropy: 0.5108256237659907

# %%
# also correct, written out for N=2 events
H = -( p[0]*np.log(q[0]) + p[1]*np.log(q[1]) )
print('Correct entropy: ' + str(H))

# simplification
H = -np.log(q[0])
print('Manually simplified: ' + str(H))
# Out:
# Correct entropy: 0.5108256237659907
# Manually simplified: 0.5108256237659907

# %%
# now using pytorch
import torch
import torch.nn.functional as F

# note: inputs must be Tensors
q_tensor = torch.Tensor(np.array(q))
print(f"q_tensro:{q_tensor}")
p_tensor = torch.Tensor(np.array(p))
print(f"p_tensor:{p_tensor}")

F.binary_cross_entropy(q_tensor,p_tensor) # pred comes in first, label comes in the second argument
# Out:
# q_tensro:tensor([0.9000, 0.1000])
# p_tensor:tensor([1., 0.])
# tensor(0.1054)
